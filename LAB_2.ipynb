# %% [markdown]
# <a href="https://colab.research.google.com/github/priyadarshanitamanna-a11y/AI-LAB-PROGRAM-1/blob/main/LAB_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem 2: The Water Jug Problem (Solved using BFS)
# Problem Statement:
# You are given two jugs: Jug A with a capacity of 4 litres, and Jug B with a capacity of 3 litres. Neither jug has any markings on it. Using only the following operations — (i) fill a jug completely, (ii) empty a jug completely, (iii) pour water from one jug into the other until either the first jug is empty or the second jug is full — determine the minimum sequence of steps needed to measure out exactly 2 litres of water in any one jug.

# %%
from collections import deque

# Capacities of the two jugs
CAP_A = 4
CAP_B = 3

# BFS queue: (state, path)
# State = (amount_in_A, amount_in_B)
queue = deque([((0, 0), [])])

# Keep track of visited states
visited = set()
visited.add((0, 0))

while queue:
    (a, b), path = queue.popleft()

    # Goal: exactly 2 litres in either jug
    if a == 2 or b == 2:
        print("Minimum steps:", len(path))
        print("\nSequence of operations:")

        for i, operation in enumerate(path, 1):
            print(f"{i}. {operation}")

        print(f"\nFinal state: ({a}, {b})")
        break

    # Generate all possible next states

    next_states = []

    # 1. Fill Jug A
    next_states.append(((CAP_A, b), "Fill Jug A"))

    # 2. Fill Jug B
    next_states.append(((a, CAP_B), "Fill Jug B"))

    # 3. Empty Jug A
    next_states.append(((0, b), "Empty Jug A"))

    # 4. Empty Jug B
    next_states.append(((a, 0), "Empty Jug B"))

    # 5. Pour A -> B
    amount = min(a, CAP_B - b)
    next_states.append(((a - amount, b + amount), "Pour A -> B"))

    # 6. Pour B -> A
    amount = min(b, CAP_A - a)
    next_states.append(((a + amount, b - amount), "Pour B -> A"))

    # Add unvisited states to the queue
    for new_state, operation in next_states:
        if new_state not in visited:
            visited.add(new_state)
            queue.append((new_state, path + [operation]))
# Out:
# Minimum steps: 4
#
# Sequence of operations:
# 1. Fill Jug B
# 2. Pour B -> A
# 3. Fill Jug B
# 4. Pour B -> A
#
# Final state: (4, 2)
